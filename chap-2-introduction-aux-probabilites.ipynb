# %% [markdown]
# # Introduction aux probabilités
#
# Les probabilités partent d'une hypothèse mathématique.
#
# ## Etapes pour calculer une probabilité
#
# 1. Définir l'univers
# 2. Définir l'évènement d'intérêt
# 3. Compter
#
# ### Exemple de calcul d'une probabilité pour le lancé d'une pièce de monnaie
#
# 1. Définir l'univers : $\boxed{\Omega = \{pile;face\}}$
# 2. Définir l'évènement d'intérêt : $\boxed{A=\{pile\}}$ **⇒ Quelle est la probabilité de tomber sur pile ?**
# 3. Compter : $\boxed{P(A) = \frac{\#A}{\#\Omega} = \frac{1}{2}=\textbf{0,5}}$
#
# Le caractère # signifie ***cardinal*** qui correspond au nombre d'éléments de A par exemple dans le cas de #A
#
# ### Exemple de calcul d'une probabilité pour le lancé d'un dé
#
# 1. Définir l'univers : $\boxed{\Omega = \{1;2;3;4;5;6\}}$
# 2. Définir l'évènement d'intérêt : $\boxed{B=\{6\}}$ **⇒ Quelle est la probabilité de tomber sur 6 ?**
# 3. Compter : $\boxed{P(B) = \frac{\#B}{\#\Omega} = \frac{1}{6}\simeq \textbf{0,17}}$
#
# **La formule $\boxed{P(A) = \frac{\#A}{\#\Omega}}$ est valable seulement dans le cas où les possibilités ont la même chance de se réaliser (lancé de dé ou d'une pièce par exemple).**
#
# ## Intersection, Union et Complémentaire
#
# Exemple sur un jeu de 52 cartes
#
# 1. Univers : $\boxed{\Omega = \{1_ {coeur};2_{coeur};3_{coeur};etc.\}}$
# 2. Evènements :
#     - $\boxed{A=\{Tirer~un~coeur\}}$
#     - $\boxed{B=\{Tirer~une~figure~:~valet,~dame,~ou~roi\}}$
# 3. Compter :
#
# $\boxed{P(A) = \frac{\#A}{\#\Omega} = \frac{13}{52}=\textbf{0,25}}$
#
# $\boxed{P(B) = \frac{\#B}{\#\Omega} = \frac{12}{52}\simeq \textbf{0,23}}$
#
# ### Le complémentaire (l'opposé d'avoir la probabilité de A)
#
# $\boxed{P(\bar{A}) = 1-P(A) = \frac{52-13}{52}=\frac{39}{52}=\textbf{0,75}}$
#
# ### L'intersection (ET)
#
# Probabilité d'avoir l'évènement A et l'évènement B.
#
# Dans notre cas, c'est la probabilité d'avoir un valet, une dame ou un roi en cœur.
#
# $\boxed{P(A\cap B)=\frac{3}{52}\simeq \textbf{0,06}}$
#
# ### L'union (OU)
#
# Probabilité d'avoir l'évènement A ou l'évènement B.
#
# Dans notre cas, c'est la probabilité d'avoir un valet, une dame ou un roi ou un cœur.
#
# **Attention, on ne doit pas intégrer la probabilité de l'intersection (correspond au dernier élément de la formule suivante).**
#
# $\boxed{{P(A\cup B)}=P(A)+P(B)-P(A\cap B)}$
#
# $\boxed{{P(A\cup B)}=\frac{13+12-3}{52}=\frac{22}{52}\simeq \textbf{0,42}}$
#
# ## Evènements indépendants et dépendants
#
# Exemple sur un jeu de 52 cartes
#
# ### Tirage AVEC remise
#
# **Expérience :**  On fait 2 tirages successifs AVEC remise (c'est-à-dire que l'on remet la carte tirée dans le jeu, ainsi, on peut tirer 2 fois la même carte)
#
# **Evènements :**
#
# $\boxed{A=\{Tirer~un~roi~de~coeur~au~1er~tirage\}}$
#
# $\boxed{B=\{Tirer~un~roi~de~coeur~au~2eme~tirage\}}$
#
# **Calcul :**
#
# $\boxed{P(A) = \frac{1}{52}}$
#
# $\boxed{P(B) = \frac{1}{52}}$
#
# $\boxed{P(A\cap B)=\left(\frac{1}{52}\right) \times \left(\frac{1}{52}\right)= \frac{1}{2704}}$
#
# Dans ce cas, on peut voir que l'on utilise la formule suivante, ainsi on peut dire que les évènements sont indépendants et inversement si nous savons que l'expérience utilise des tirages indépendants alors on peut utiliser la formule de la probabilité suivante.
#
# $\boxed{{P(A\cap B)}=P(A).P(B)}$
#
# **Un tirage avec remise indique que nous sommes dans des évènements indépendants**.
#
# ### Tirage SANS remise
#
# **Expérience :**  On fait 2 tirages successifs SANS remise (c'est-à-dire que l'on remet la carte tirée dans le jeu, ainsi, on ne peut pas tirer 2 fois la même carte)
#
# $\boxed{\#\Omega = 52 \times 51 = 2652}$
#
# **Evènements :**
#
# $\boxed{A=\{Tirer~un~roi~de~coeur~au~1er~tirage\}}$
#
# $\boxed{B=\{Tirer~un~roi~de~coeur~au~2eme~tirage\}}$
#
# **Interprétation :**
#
# $\boxed{P(A) = \frac{1}{52}}$
#
# $\boxed{P(B) = \frac{1}{52}}$
#
# $\boxed{P(A\cap B)=\textbf{0}\neq P(A)\times P(B)}$
#
# En effet, il est impossible de tirer un roi de cœur alors qu'on l'a déjà tiré avec un tirage SANS remise.
#
# **La probabilité n'est pas égale au produit des probabilités de A et de B, alors on peut dire que nos évènements sont dépendants.**
#
# **Expérience :**  On fait 2 tirages successifs SANS remise (c'est-à-dire que l'on remet la carte tirée dans le jeu, ainsi, on ne peut pas tirer 2 fois la même carte)
#
# $\boxed{\Omega = \{1;2;3;4;5;6\}}$
#
# **Evènements :**
#
# $\boxed{A=\{Tirer~un~roi~de~coeur~au~1er~tirage\}}$
#
# $\boxed{C=\{Tirer~un~coeur~au~2eme~tirage\}}$
#
# **Interprétation :**
#
# $\boxed{P(A) = \frac{1}{52}}$ en cas d'évènement indépendants
#
# $\boxed{P(C) = \frac{13}{52}}$ en cas d'évènement indépendants
#
# Si on liste les tirages possibles d'après les ***évènements*** ci-dessus :
#
# | Tirage 1 | Tirage 2 |
# | --- | --- |
# | Roi ❤️ | 1 ❤️ |
# | Roi ❤️ | 2 ❤️ |
# | Roi ❤️ | 3 ❤️ |
# | Roi ❤️ | 4 ❤️ |
# | Roi ❤️ | 5 ❤️ |
# | Roi ❤️ | 6 ❤️ |
# | Roi ❤️ | 7 ❤️ |
# | Roi ❤️ | 8 ❤️ |
# | Roi ❤️ | 9 ❤️ |
# | Roi ❤️ | 10 ❤️ |
# | Roi ❤️ | V ❤️ |
# | Roi ❤️ | D ❤️ |
#
# ⇒ Nous retrouvons 12 lignes soit la probabilité suivante :
#
# $\boxed{P(A\cap C)=\frac{12}{52 \times 51} = \frac{12}{2652}}$
#
# **La formule générale pour la gestion des évènements dépendants (probabilités conditionnelles) est la suivante :**
#
# $\boxed{{P(A\cap B)}=P(A)\times P(B|A)}$ **Formule évènements dépendants**
#
# Correspond à la probabilité de l'évènement **B sachant** que **A** s'est réalisé.
#
# <aside>
# 😉 Dans le cas d'évènements indépendants $P(B|A)=P(B)$, nous retournons alors, bien sur la formule $\boxed{P(A\cap B)=P(A)\times P(B)}$
#
# </aside>
#
# ## Calcul de probabilités
#
# **Expérience :**  On fait 2 tirages successifs AVEC remise
#
# **Univers :** $\boxed{\Omega = \{52~cartes\}}$
#
# **Evènements :** $\boxed{M=\{Tirer~exactement~un~roi~de~coeur\}}$
#
# **⇒ Description de nouveaux évènements en fonction de l'évènement M pour simplifier le calcul**
#
# $\boxed{R_1=\{Tirer~un~roi~de~coeur~au~1^{er}~tirage\}}$
#
# $\boxed{R_2=\{Tirer~un~roi~de~coeur~au~2^{ème}~tirage\}}$
#
# - ***Arbre des possibilités AVEC remise***
#     - $R_1$
#         - $R_2$
#
#             **~~⇒ 2 rois de cœur, ne correspond pas à notre évènement M~~**
#
#         - $\bar{R_2}$
#
#             **⇒ 1 roi de cœur,**  $\boxed{P(R_1\cap \bar{R_2})=P(R_1) \times P(\bar{R_2}) =\left(\frac{1}{52} \times \frac{51}{52}\right)}$
#
#     - $\bar{R_1}$
#         - $R_2$
#
#             **⇒ 1 roi de cœur,** $\boxed{P(\bar{R_1}\cap R_2)=P(\bar{R_1}) \times P(R_2)=\left(\frac{51}{52} \times \frac{1}{52}\right)}$
#
#         - $\bar{R_2}$
#
#             **~~⇒ 0 roi de cœur, ne correspond pas à notre évènement M~~**
#
#
# $\boxed{P(M)=P\left(R_1\cap \bar{R_2}\right) \cup P\left(\bar{R_1}\cap R_2\right) = \left(\frac{1}{52} \times \frac{51}{52}\right)+\left(\frac{51}{52} \times \frac{1}{52}\right) = \left(\frac{51}{2704}\right)+\left(\frac{51}{2704}\right)= \frac{102}{2704}}$
#
# **Expérience :**  On fait 2 tirages successifs AVEC remise
#
# **Univers :** $\boxed{\Omega = \{52~cartes\}}$
#
# **Evènements :** $\boxed{M=\{Tirer~exactement~un~roi~de~coeur\}}$
#
# **⇒ Description de nouveaux évènements en fonction de l'évènement M pour simplifier le calcul**
#
# $\boxed{R_1=\{Tirer~un~roi~de~coeur~au~1^{er}~tirage\}}$
#
# $\boxed{R_2=\{Tirer~un~roi~de~coeur~au~2^{ème}~tirage\}}$
#
# - ***Arbre des possibilités AVEC remise***
#     - $R_1$
#         - $R_2$
#
#             **~~⇒ 2 rois de cœur, impossible et ne correspond pas à notre évènement M~~**
#
#         - $\bar{R_2}$
#
#             **⇒ 1 roi de cœur,**  $\boxed{P(R_1\cap \bar{R_2})= P(R_1) \times P(\bar{R_2}|R_1) =\left(\frac{1}{52} \times 1\right)}$ On **multiplie par 1** car la probabilité de ne pas tirer un roi de cœur alors qu'on l'a déjà tiré 1er tirage est forcément vrai
#
#     - $\bar{R_1}$
#         - $R_2$
#
#             **⇒ 1 roi de cœur,** $\boxed{P(\bar{R_1}\cap R_2)=P(\bar{R_1}) \times P(R_2|\bar{R_1}) =\left(\frac{51}{52} \times \frac{1}{51}\right)=\frac{1}{52}}$
#
#         - $\bar{R_2}$
#
#             **~~⇒ 0 roi de cœur, ne correspond pas à notre évènement M~~**
#
#
# $\boxed{P(M)=P\left(R_1\cap \bar{R_2}\right) \cup P\left(\bar{R_1}\cap R_2\right) = \left(\frac{1}{52} \right)+\left(\frac{1}{52} \right) = \frac{2}{52}}$
#
# ## Loi des probabilités totales
#
# Elle correspond en gros à dessiner un arbre comme vu précédemment.
#
# - ***Arbre des possibilités***
#     - $B_1$
#         - $A$
#         - $\bar{A}$
#     - $B_2$
#         - $A$
#         - $\bar{A}$
#     - $B_3$
#         - $A$
#         - $\bar{A}$
#     - $...$
#         - $A$
#         - $\bar{A}$
#
# Si $(B_i)_{i \in I}$ est une suite d'évènements distincts (leur intersection est vide) et dont l'union est égale à l'univers, alors la probabilité de A est la somme des probabilités conditionnelles de A sachant Bi multiplié par Bi, comme ci-après :
#
# $\boxed{P(A) = \sum_{i \in I} P(A|B_{i}) \times P(B_{i})}$
#
# $\boxed{P(A) = (P(A|B_{1}) \times P(B_{1})) + (P(A|B_{2}) \times P(B_{2})) + ...}$
#
# **Expérience :**  Au Blackjack, quelle est la probabilité de faire un score de 20 avec les 2 premières cartes ?
#
# **Univers :** $\boxed{\Omega = \{52~cartes\}}$
#
# **Evènements :** $\boxed{A=\{Faire~un~score~de~20~avec~les~2~premières~cartes\}}$
#
# **⇒ Description de nouveaux évènements en fonction de l'évènement A pour simplifier le calcul**
#
# $\boxed{B_1=\{Avoir~un~As~(=1~ou~11)\}}$
#
# $\boxed{B_2=\{Avoir~une~figure~ou~un~10\}}$
#
# $\boxed{B_3=\{Avoir~un~9\}}$
#
# $\boxed{B_4=\{Avoir~autre~chose\}}$ (impossible d'avoir 20 si on a une carte de type B4)
#
# $\boxed{P(B_1)=\frac{1}{13}}$ ⇒ $\boxed{P(A|B_1)=\frac{1}{13}}$ Si on a tiré un As (B1), alors il nous faut un 9 derrière, soit 1/13
#
# $\boxed{P(B_2)=\frac{4}{13}}$ ⇒ $\boxed{P(A|B_2)=\frac{4}{13}}$ Si on a tiré une figure ou un 10 (B2), alors il nous faut retirer une figure ou un 10, soit 4/13
#
# $\boxed{P(B_3)=\frac{1}{13}}$ ⇒ $\boxed{P(A|B_3)=\frac{1}{13}}$ Si on a tiré un 9 (B3), alors il nous faut retirer un As, soit 1/13
#
# $\boxed{P(B_4)=\frac{7}{13}}$ ⇒ $\boxed{P(A|B_4)=0}$ Impossible
#
# $\boxed{P(A) = (P(A|B_{1}) \times P(B_{1})) + (P(A|B_{2}) \times P(B_{2})) + ...}$
#
# $\boxed{P(A) = \left(\frac{1}{13} \times \frac{1}{13}\right) + \left(\frac{4}{13} \times \frac{4}{13}\right) + \left(\frac{1}{13} \times \frac{1}{13}\right) = \frac{18}{169} }$
#
# ## Le théorème de Bayes
#
# En partant de la formule des probabilités conditionnelles suivante :
#
# $\boxed{{P(A\cap B)}=P(A)\times P(B|A)}$
#
# Et d'après la **commutativité**, $P(A \cap B) = P(B \cap A)$, on peut dire que :
#
# $\boxed{{P(A\cap B)}=P(B)\times P(A|B)}$ , soit : $\boxed{P(A)\times P(B|A)=P(B)\times P(A|B)}$
#
# On divise par la $P(B)$ de chaque côté :
#
# $\boxed{\frac{P(A)\times P(B|A)}{P(B)}=\frac{P(B)\times P(A|B)}{P(B)}}$
#
# **La formule du théorème de Bayes**
#
# Nous supprimons $P(B)$ sur l'équation de droite et passons $P(A|B)$ à gauche
#
# $\boxed{P(A|B)=\frac{P(A)\times P(B|A)}{P(B)}}$
#
# $\boxed{P(A|B)=\frac{P(B|A)\times P(A)}{(P(B|A)\times P(A)) + (P(B|\bar{A})\times P(\bar{A}))}}$
#
# **Exemple :** Se faire dépister dans un laboratoire pour une maladie.
#
# Le test n'est pas fiable à 100% :
#
# - Si le patient est malade, le test est positif dans 99% du temps
# - Si le patient n'est pas malade, le test est négatif dans 95% du temps
# - La maladie touche 1 personne sur 1000 dans la population
#
# Je me fais tester et le test est positif. Quelle est la probabilité que le test se trompe alors que l'on a été testé positif ?
#
# $\boxed{A=\{Etre~malade\}}$
#
# $\boxed{B=\{Le~test~est~positif\}}$
#
# Si on reprend les statistiques :
#
# - Si le patient est malade, le test est positif dans 99% du temps ⇒ $\boxed{P(B|A)=0,99}$
# - Si le patient n'est pas malade, le test est négatif dans 95% du temps ⇒ $\boxed{P(\bar{B}|\bar{A})=0,95}$
# - La maladie touche 1 personne sur 1000 dans la population ⇒ $\boxed{P(A)=0,001}$
#
# $\boxed{P(A|B)=\frac{P(A)\times P(B|A)}{P(B)} = \frac{0,001\times 0,99}{(P(B|A)\times P(A)) + (P(B|\bar{A})\times P(\bar{A}))}}$
#
# $\boxed{P(A|B)=\frac{0,001\times 0,99}{(0,99\times 0,001) + (0,05\times 0,999)}\simeq 0,02\simeq \textbf{2\%~de~chance~d'être~malade~alors~que~le~test~est~positif}}$
#
# Cela parait contre-intuitif, c'est ce que l'on appelle un biais cognitif ou paradoxe probabiliste.
#
# Ce chiffre est ridiculement faible car, pour 1000 personnes testées, 50 personnes sont testés positives alors qu'elles ne sont pas malades (sur la population totale de 1000 personnes), donc le test n'est vraiment pas fiable.
#
# ## Permutations
#
# Une permutation correspond à changer l'ordre des cartes dans l'exemple d'un jeu de cartes.
#
# Dans notre jeu de cartes, par exemple, le nombre de permutations est de : $Permutations=52!\simeq 8,065^{67}$ ça fait beaucoup de possibilités 😉
#
# **Exemple :** On tire une main de poker à 4 cartes (4 au lieu de 5 car arbre plus court 🙂). Quelle est la probabilité d'avoir un carré d'as ?
#
# Dans ce cas, nous sommes donc dans un tirage sans remise, car c'est comme si on piochait la 1ère carte, puis la 2ème...
#
# - ***Arbre des possibilités***
#     - $As$
#         - $As$
#             - $As$
#                 - $As$
#
#                     $\boxed{P(A)=\left(\frac{4}{52} \times \frac{3}{51} \times \frac{2}{50} \times \frac{1}{49}\right)}$ Seule une seule branche nous intéresse, car il y a qu'une seule possibilité.
#
#
# Au lieu de l'arbre, nous allons voir comment réaliser cela via les permutations.
#
# **La formule générale de la permutation est :**
#
# $\boxed{Permutations=\frac{n!}{(n-k)!}}$ , $n$ étant le nombre total de cartes dans notre exemple et $k$ le nombre de cartes tirées
#
# Ainsi, le nombre de permutations pour 4 cartes tirées à partir d'un jeu de 52 cartes :
#
# $\boxed{Permutations=\frac{52!}{(52-4)!} = 52 \times 51 \times 50 \times 49 = 6497400}$
#
# Ensuite, on doit calculer le nombre de possibilité pour l'évènement d'avoir un carré. On regarde le nombre de permutations pour un carré d'As soit $**4!**$
#
# $\boxed{P(A)=\cfrac{4!}{\cfrac{52!}{(52-4)!}}=\cfrac{4 \times 3 \times 2 \times 1}{52 \times 51 \times 50 \times 49}}$ **Soit la probabilité déduite via l'arbre ci-dessus**
#
# ## Combinaisons
#
# Une combinaison correspond à un ensemble, dans notre exemple, un ensemble de cartes, l'ordre n'est pas important. Par exemple, pour avoir les 4 As, nous avons une seule combinaison.
#
# **Exemple :** On reprend le même exemple, on tire une main de poker à 4 cartes. Quelle est la probabilité d'avoir un carré d'as ? (sans remise)
#
# Pour les $4 \times 3 \times 2 \times 1=\textbf{24}$ permutations visibles ci-dessous, nous avons bien une seule combinaison.
#
# | ❤️ ♠️ ♦️ ♣️ | 1ère permutation | 1ère combinaison |
# | --- | --- | --- |
# | ❤️ ♠️ ♣️ ♦️ | 2ème permutation | 1ère combinaison |
# | ❤️ ♣️ ♠️ ♦️ | 3ème permutation | 1ère combinaison |
# | ❤️ ♣️ ♦️ ♠️ | 4ème permutation | 1ère combinaison |
# | ... | nième permutation | 1ère combinaison |
#
# $\boxed{Combinaisons= \frac{n!}{(n-k)! \times k!}}$
#
# $\boxed{Combinaisons= \begin{pmatrix}
# n\\
# k
# \end{pmatrix}}$ est une autre manière d'écrire une combinaison. On dit $k$ parmi $n$. Dans notre exemple, on dit 4 parmi 52 par exemple.
#
# $\boxed{Combinaisons=\frac{ \color{red}{52\times51\times50\times49}}{4!}=\frac{\color{red}52!}{{\color{red}(52-4)!} \times 4!}=\begin{pmatrix}
# 52\\
# 4
# \end{pmatrix}}$ **correspond au nombre de permutations**
#
# $\boxed{P(A)=\cfrac{\color{green}1}{\begin{pmatrix}
# 52\\
# 4
# \end{pmatrix}}=\cfrac{4 \times 3 \times 2 \times 1}{52 \times 51 \times 50 \times 49}}$ **correspond au nombre de combinaisons possibles comme il y a une seule possibilité alors 1 au numérateur**
#
# ## Calcul de dénombrement
#
# **Exemple :** Maintenant, on tire une main de poker à ***5 cartes***. Quelle est la probabilité d'avoir un carré d'as ? (sans remise)
#
# ### Via les permutations
#
# D'abord, on calcule la probabilité d'avoir 4 As et la dernière une autre carte.
#
# On commence par définir le nombre de permutations qui est de $4~As\implies 4!$ comme vu précédemment.
#
# Pour la dernière carte, nous avons $52-4\implies 48~possiblités$
#
# Le nombre de permutations pour le cas où nous avons les 4 As puis une autre carte est de $4! \times 48$
#
# Comme nous tirons 5 cartes, il suffit de multiplier par 5 pour obtenir le nombre de possibilités.
#
# $\boxed{Nombre~possiblités~de~ l'évènement=4! \times 48 \times 5}$
#
# $\boxed{P(A)=\cfrac{4! \times 48 \times 5}{\cfrac{\color{red}52!}{\color{red}(52-5)!}}}$ **correspond aux nombre de permutations du tirage**
#
# ### Via les combinaisons
#
# Beaucoup plus simple !! Il y a une combinaison possible d'avoir les 4 As et ensuite 48 combinaisons d'avoir l'autre carte.
#
# $\boxed{Nombre~possiblités~de~ l'évènement= 1\times 48}$
#
# $\boxed{P(A)=\cfrac{48}{\begin{pmatrix}
# 52\\
# 5
# \end{pmatrix}}}$
